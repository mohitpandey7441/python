# %% [markdown]
# # 25th

# %% [markdown]
# # Dictionary

# %%
# Dictionary is a mutable data type in Python. 
# A python dictionary is a collection of key and value pairs separated by a colon (:) & enclosed 
# in curly braces {}. 
# Keys must be unique in a dictionary, duplicate values are allowed.

# %% [markdown]
# # Create Dictionary

# %%
mydict = {} # Empty dictionary
mydict
# Out:
# {}

# %%
type(mydict)
# Out:
# dict

# %%
mydict = {1:'one', 2:'two', 3:'three'} # dictionary with integer keys
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = dict({1:'one' , 2:'two', 3:'three'})  # Create dictionary using dict() 
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
mydict = {'A' :'one',  'B':'two', 'C':'three'}  # dictionary with character keys() 
mydict
# Out:
# {'A': 'one', 'B': 'two', 'C': 'three'}

# %%
mydict = {1:'one' , 'A':'two' , 3:'three'} # dictionary with mixed keys 
mydict
# Out:
# {1: 'one', 'A': 'two', 3: 'three'}

# %%
mydict.keys() # Return Dictionary Keys using keys() method
# Out:
# dict_keys([1, 'A', 3])

# %%
mydict.values() # Return Dictionary values using values() method
# Out:
# dict_values(['one', 'two', 'three'])

# %%
mydict.items() # Access each key-value pair within a dictionary
# Out:
# dict_items([(1, 'one'), ('A', 'two'), (3, 'three')])

# %%
mydict = {1:'one', 2:'two', 'A':{'Name':'asif' , 'Age': 25} , 'B': {'Bat' , 'Cat', 'Hat'}}
mydict
# Out:
# {1: 'one',
#  2: 'two',
#  'A': {'Name': 'asif', 'Age': 25},
#  'B': {'Bat', 'Cat', 'Hat'}}

# %%
keys = {'A' , 'B' , 'C' , 'D'}
mydict3 = dict.fromkeys(keys) # Create a dictionary from a sequence of keys
mydict3
# Out:
# {'D': None, 'B': None, 'A': None, 'C': None}

# %%
keys = {'A' , 'B' , 'C' , 'D'}
value = 10
mydict3 = dict.fromkeys(keys, value) # Create a dictionary from a sequence of keys
mydict3
# Out:
# {'D': 10, 'B': 10, 'A': 10, 'C': 10}

# %%
keys = {'A' , 'B' , 'C' , 'D'}
value = {10, 20 , 30}
mydict3 = dict.fromkeys(keys, value) # Create a dictionary from a sequence of keys
mydict3
# Out:
# {'D': {10, 20, 30}, 'B': {10, 20, 30}, 'A': {10, 20, 30}, 'C': {10, 20, 30}}

# %%
value.append(40) 
mydict3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 value.aad(40)
#       2 mydict3
#
# AttributeError: 'set' object has no attribute 'aad'

# %% [markdown]
# # Accessing Items

# %%
mydict = {1: 'one', 2:'two' , 3:'three' , 4:'four'}
mydict
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
mydict[1] # Access item using key
# Out:
# 'one'

# %%
mydict.get(1) # Access item using get method
# Out:
# 'one'

# %%
mydict1 = {'Name' :'Mohit' , 'ID': 1234, 'DOB':2000, 'Job':'Data Analyst'}
mydict1
# Out:
# {'Name': 'Mohit', 'ID': 1234, 'DOB': 2000, 'Job': 'Data Analyst'}

# %%
mydict1['Name'] # Access item using key
# Out:
# 'Mohit'

# %%
mydict.get('Job') # Access item using get method
# Out:
# 'Data Analysist'

# %% [markdown]
# # Add , Remove & Change items

# %%
mydict1 = {'Name':'Arif' , 'ID': 25 , 'DOB': 1993 , 'Address':'Hilsini'}
mydict1
# Out:
# {'Name': 'Arif', 'ID': 25, 'DOB': 1993, 'Address': 'Hilsini'}

# %%
mydict1['DOB'] = 1992 # Changing Dictionary Items 
mydict1['Address'] = 'Delhi' 
mydict1
# Out:
# {'Name': 'Arif', 'ID': 25, 'DOB': 1992, 'Address': 'Delhi'}

# %%
dict1 = {'DOB':1995}
mydict1.update(dict1)
mydict1
# Out:
# {'Name': 'Arif', 'ID': 25, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1['Job'] = 'Analyst' # Adding items in the dictionary 
mydict1
# Out:
# {'Name': 'Arif', 'ID': 25, 'DOB': 1995, 'Address': 'Delhi', 'Job': 'Analyst'}

# %%
mydict1.pop('Job') # Removing items in the dictionary using Pop method 
mydict1
# Out:
# {'Name': 'Arif', 'ID': 25, 'DOB': 1995, 'Address': 'Delhi'}

# %%
mydict1.popitem() # A random item is removed 
mydict1
# Out:
# {'Name': 'Arif', 'ID': 25, 'DOB': 1995}

# %%
del[mydict1['ID']] # Removing items using del method
mydict1
# Out:
# {'Name': 'Arif', 'DOB': 1995}

# %%
mydict1.clear() # Delete all items of the dictionary using clear method 
mydict1
# Out:
# {}

# %%
del mydict1 # Delete dictionary object
mydict1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 2
#       1 del mydict1 # Delete dictionary object
# ----> 2 mydict1
#
# NameError: name 'mydict1' is not defined

# %% [markdown]
# # Copy Dictionary

# %%
mydict = {'Name':'Arif', 'ID':123 , 'DOB':2005 , 'Address':'Hilsini'}
mydict
# Out:
# {'Name': 'Arif', 'ID': 123, 'DOB': 2005, 'Address': 'Hilsini'}

# %%
mydict1 = mydict # Create a new reference "mydict1"

# %%
id(mydict) , id(mydict1)  # The address of both mydict & mydict1 will be the same
# Out:
# (2323738602880, 2323738602880)

# %%
mydict2 = mydict.copy() # Create a copy of the dictionary

# %%
id(mydict2)  # The address of mydict2 will be different from mydict because mydict
# Out:
# 2323738122304

# %%
mydict['Address'] = 'Mumbai'
mydict
# Out:
# {'Name': 'Arif', 'ID': 123, 'DOB': 2005, 'Address': 'Mumbai'}

# %%
mydict1 # mydict1 will be also impacted as it is pointing to the same dictionary
# Out:
# {'Name': 'Arif', 'ID': 123, 'DOB': 2005, 'Address': 'Mumbai'}

# %%
mydict2  # Copy of list won't be impacted due to the changes made in the original
# Out:
# {'Name': 'Arif', 'ID': 123, 'DOB': 2005, 'Address': 'Hilsini'}

# %% [markdown]
# # Loop through a Dictionary

# %%
mydict1 = {'name':'Arif' , 'ID':123 , 'DOB':2007, 'Address':'Mumbai'}
mydict1
# Out:
# {'name': 'Arif', 'ID': 123, 'DOB': 2007, 'Address': 'Mumbai'}

# %%
for i in mydict1:
     print(i , ':' , mydict1[i]) # Key & value pair
# Out:
# name : Arif
# ID : 123
# DOB : 2007
# Address : Mumbai

# %%
for i in mydict1:
    print(mydict1[i]) # Dictionary items
# Out:
# Arif
# 123
# 2007
# Mumbai

# %% [markdown]
# # Dictionary Membership

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'} 
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
'Name' in mydict1 # Test if a key is in a dictionary or not
# Out:
# True

# %%
'Asif' in mydict1 # Membership test can be only done for keys.
# Out:
# False

# %%
'ID' in mydict1
# Out:
# True

# %%
'Address' in mydict1
# Out:
# False

# %% [markdown]
#  # All / Any

# %% [markdown]
# # The All() method returns:

# %%
# True - If all all keys of the dictionary are true 
# False - If any key of the dictionary is false 
#The any() function returns True if any key of the dictionary is True. If not, any() returns False.

# %%
mydict1 = {'Name':'Asif' , 'ID': 12345 , 'DOB': 1991 , 'Job': 'Analyst'} 
mydict1
# Out:
# {'Name': 'Asif', 'ID': 12345, 'DOB': 1991, 'Job': 'Analyst'}

# %%
all(mydict1) # Will Return false as one value is false (Value 0)
# Out:
# True
